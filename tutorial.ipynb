# %%
import sys
sys.path.append('./libs')
import numpy as np
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina' 
import cv2
from deblur import *

# %%
cat_blur = cv2.imread('images/blur.jpg')

# %%
plt.figure(figsize=(5,5))
plt.imshow(cat_blur[:,:,::-1])
plt.title('Blurred cat')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
cat_deblur, cat_psf = bayes_deblur(cat_blur, 21, maxiter=15,maxit_u=15,maxit_h=15, Lp=0, psf=None, params=None)

# %%
plt.figure(figsize=(5,5))
plt.imshow(cat_deblur[:,:,::-1])
plt.title('Deblurred cat')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
plt.imshow(cat_psf,cmap='Greys_r')
plt.title('Possible blur kernel')
plt.xticks([])
plt.yticks([])
plt.show()
